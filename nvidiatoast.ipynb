# %% [markdown]
# <a href="https://colab.research.google.com/github/lunatrifx/Project-Summitseeker/blob/main/nvidiatoast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yt-dlp
# !pip install ffpyplayer

# %%
import cv2
from google.colab.patches import cv2_imshow # only if you're running and compiling this on colab
import time
import numpy as np
import yt_dlp
import sys
import os
from ffpyplayer.player import MediaPlayer
import ipywidgets as widgets
import IPython.display
from IPython.display import display, clear_output

import warnings
warnings.filterwarnings("ignore")

# %%
# set up a timer (up to 4 minutes)
timer = time.time() + 240

# %%
# download a video via youtube link
# !yt-dlp https://www.youtube.com/watch?v=7htmVxGfS08
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7htmVxGfS08
# [youtube] 7htmVxGfS08: Downloading webpage
# [youtube] 7htmVxGfS08: Downloading ios player API JSON
# [youtube] 7htmVxGfS08: Downloading m3u8 information
# [info] 7htmVxGfS08: Downloading 1 format(s): 247+251
# [download] Bread spinning for 1 hour [7htmVxGfS08].webm has already been downloaded

# %%
# Create widgets that allow users to select the amount of time for their toast
toasty = widgets.Text(value='toast')
timer = widgets.IntSlider(description='time:', min=1, max=4)
display(toasty, timer)
# Out:
# Text(value='toast')
# IntSlider(value=1, description='time:', max=4, min=1)

# %%
print(toasty.value + ' is set to ' + str(timer.value) + ' minute(s)')
# record this value to be set as the timer
timer = time.time() + (timer.value * 60)
# Out:
# toast is set to 1 minute(s)

# %%
while time.time() < timer:
  print(timer - time.time())
# Out:
# Streaming output truncated to the last 5000 lines.
# 1.5829472541809082
# 1.5829339027404785
# 1.582921028137207
# 1.5829074382781982
# 1.5828936100006104
# 1.5828797817230225
# 1.5828661918640137
# 1.5828533172607422
# 1.5828399658203125
# 1.582827091217041
# 1.5828135013580322
# 1.5827996730804443
# 1.5827865600585938
# 1.5827720165252686
# 1.582758903503418
# 1.5827457904815674
# 1.5827312469482422
# 1.5827181339263916
# 1.5827043056488037
# 1.5826902389526367
# 1.5826740264892578
# 1.5826606750488281
# 1.5826468467712402
# 1.5826337337493896
# 1.582620620727539
# 1.5825934410095215
# 1.582578420639038
# 1.5825650691986084
# 1.5825517177581787
# 1.5825388431549072
# 1.5825250148773193
# 1.5825109481811523
# 1.5824971199035645
# 1.5824840068817139
# 1.5824708938598633
# 1.5824575424194336
# 1.582444667816162
# 1.5824310779571533
# 1.5824167728424072
# 1.582401990890503
# 1.5823016166687012
# 1.582287311553955
# 1.5822737216949463
# 1.5822603702545166
# 1.582247018814087
# ...

# %%
# while timer is on going, play a video
while time.time() < timer:
 # Play video from a file
  cap = cv2.VideoCapture('/content/Bread.mp4') # Remember to change video path before testing
# audio extension
player = MediaPlayer('/content/Bread.mp4')

# Throw error if video is not opened
if(cap.isOpened() == False):
    print("Error opening video file")
    print("file exists? Reason:", os.path.exists('/content/Bread.mp4'))
    sys.exit()

# Get the frames per second of the video
while(cap.isOpened()):
    ret, frame = cap.read()
    audio_frame, val = player.get_frame()
    if ret == True:
        cv2.imshow('Frame', frame)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            if val != 'eof' and audio_frame is not None:
                #audio
                img, t = audio_frame
            break
    else:
        break

# Release the video capture object
cap.release()

# %%
# Print a message
print("Toast is ready")
# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# Toast is ready
